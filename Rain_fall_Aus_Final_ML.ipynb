# %%
# Surpress warnings:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import svm
import sklearn.metrics as metrics
from sklearn.metrics import jaccard_score, f1_score, accuracy_score, confusion_matrix, log_loss, mean_squared_error, r2_score, mean_absolute_error
# Out:
# Using matplotlib backend: <object object at 0x000001BA902A4CD0>

# %%
path='https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-ML0101EN-SkillUp/labs/ML-FinalAssignment/Weather_Data.csv'
df = pd.read_csv(path)

# %%
df.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0           W
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7           W
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1           W
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0           W
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Humidity9am  Humidity3pm  \
# 0             41          S        SSW  ...           92           84
# 1             41          W          E  ...           83           73
# 2             41        ESE        ESE  ...           88           86
# 3             41        NNE          E  ...           83           90
# 4             41        NNE          W  ...           88           74
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# <h2>Data Preprocessing</h2>

# %% [markdown]
# <h3>One Hot Encoding</h3>

# %%
df.dtypes
# Out:
# Date              object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed      int64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am       int64
# WindSpeed3pm       int64
# Humidity9am        int64
# Humidity3pm        int64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am           int64
# Cloud3pm           int64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# RainTomorrow      object
# dtype: object

# %%
#First, we need to perform one hot encoding to convert categorical variables to binary variables.
df_sydney_processed = pd.get_dummies(data=df, columns=['RainToday', 'WindGustDir', 'WindDir9am', 'WindDir3pm'])

# %% [markdown]
# Next, we replace the values of the 'RainTomorrow' column changing them from a categorical column to a binary column. We do not use the `get_dummies` method because we would end up with two columns for 'RainTomorrow' and we do not want, since 'RainTomorrow' is our target.

# %%
df_sydney_processed.replace(['No', 'Yes'], [0, 1], inplace=True)

# %%
df_sydney_processed.head()
# Out:
#        Date  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0  2/1/2008     19.5     22.4      15.6          6.2       0.0             41
# 1  2/2/2008     19.5     25.6       6.0          3.4       2.7             41
# 2  2/3/2008     21.6     24.5       6.6          2.4       0.1             41
# 3  2/4/2008     20.2     22.8      18.8          2.2       0.0             41
# 4  2/5/2008     19.7     25.7      77.4          4.8       0.0             41
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  ...  WindDir3pm_NNW  \
# 0            17            20           92  ...           False
# 1             9            13           83  ...           False
# 2            17             2           88  ...           False
# 3            22            20           83  ...           False
# 4            11             6           88  ...           False
#
#    WindDir3pm_NW  WindDir3pm_S  WindDir3pm_SE  WindDir3pm_SSE  WindDir3pm_SSW  \
# ...

# %% [markdown]
# <h2>Training Data and Test Data</h2>

# %%
df_sydney_processed.drop('Date', axis=1, inplace=True)

# %%
df_sydney_processed = df_sydney_processed.astype(float)

# %%
features = df_sydney_processed.drop(columns='RainTomorrow', axis=1)
Y = df_sydney_processed['RainTomorrow']

# %%
#New test with Standardization!
#features = preprocessing.StandardScaler().fit_transform(features)
#New test with normalization!
#features = preprocessing.normalize(features, norm='l1')

# %%
#Q1
x_train, x_test, y_train, y_test = train_test_split(features, Y, test_size=0.2, random_state=10)
print('Train set dimensions:', x_train.shape, y_train.shape)
print('Test set dimensions:', x_test.shape, y_test.shape)
# Out:
# Train set dimensions: (2616, 66) (2616,)
# Test set dimensions: (655, 66) (655,)

# %% [markdown]
# <h3>Linear Regression</h3>

# %%
#Q2
LinearReg = LinearRegression()
LinearReg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#Q3
predictions = LinearReg.predict(x_test)

# %%
#Q4
LinearRegression_MAE = mean_absolute_error(y_test, predictions)
LinearRegression_MSE = mean_squared_error(y_test, predictions)
LinearRegression_R2 = r2_score(y_test, predictions)

# %%
#Q5
data_linear = {'Metric':['MAE', 'MSE', 'R2'], 'Value':[LinearRegression_MAE, LinearRegression_MSE, LinearRegression_R2]}
Report = pd.DataFrame(data=data_linear)
print(Report)
# Out:
#   Metric     Value
# 0    MAE  0.256318
# 1    MSE  0.115721
# 2     R2  0.427132

# %% [markdown]
# <h3>KNN</h3>

# %%
#Q6
KNN = KNeighborsClassifier(n_neighbors=4)
KNN.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
#Q7
predictions = KNN.predict(x_test)

# %%
#Q8
KNN_Accuracy_Score = accuracy_score(y_test, predictions)
KNN_JaccardIndex = jaccard_score(y_test, predictions)
KNN_F1_Score = f1_score(y_test, predictions)

# %%
data_KNN = {'Metric':['Accuracy', 'Jaccard', 'F1'], 'Value':[KNN_Accuracy_Score, KNN_JaccardIndex, KNN_F1_Score]}
Report2 = pd.DataFrame(data=data_KNN)
print(Report2)
# Out:
#      Metric     Value
# 0  Accuracy  0.818321
# 1   Jaccard  0.425121
# 2        F1  0.596610

# %% [markdown]
# <h3>Decision Tree</h3>

# %%
#Q9
Tree = DecisionTreeClassifier()
Tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
#Q10
predictions = Tree.predict(x_test)

# %%
#Q11
Tree_Accuracy_Score = accuracy_score(y_test, predictions)
Tree_JaccardIndex = jaccard_score(y_test, predictions)
Tree_F1_Score = f1_score(y_test, predictions)

# %%
data_Tree = {'Metric':['Accuracy', 'Jaccard', 'F1'], 'Value':[Tree_Accuracy_Score, Tree_JaccardIndex, Tree_F1_Score]}
Report3 = pd.DataFrame(data=data_Tree)
print(Report3)
# Out:
#      Metric     Value
# 0  Accuracy  0.746565
# 1   Jaccard  0.380597
# 2        F1  0.551351

# %% [markdown]
# <h3>Logistic Regression</h3>

# %%
#Q12
x_train, x_test, y_train, y_test = train_test_split(features, Y, test_size=0.2, random_state=1)
print('Train set dimensions:', x_train.shape, y_train.shape)
print('Test set dimensions:', x_test.shape, y_test.shape)
# Out:
# Train set dimensions: (2616, 66) (2616,)
# Test set dimensions: (655, 66) (655,)

# %%
#Q13
LR = LogisticRegression(solver='liblinear')
LR.fit(x_train, y_train)
# Out:
# LogisticRegression(solver='liblinear')

# %%
#Q14
predictions = LR.predict(x_test)

# %%
predict_proba = LR.predict_proba(x_test)

# %%
#Q15
LR_Accuracy_Score = accuracy_score(y_test, predictions)
LR_JaccardIndex = jaccard_score(y_test, predictions)
LR_F1_Score = f1_score(y_test, predictions)
LR_Log_Loss = log_loss(y_test, predict_proba)

# %%
data_Logistic = {'Metric':['Accuracy', 'Jaccard', 'F1', 'Log_Loss'], 'Value':[LR_Accuracy_Score, LR_JaccardIndex, LR_F1_Score, LR_Log_Loss]}
Report4 = pd.DataFrame(data=data_Logistic)
print(Report4)
# Out:
#      Metric     Value
# 0  Accuracy  0.838168
# 1   Jaccard  0.511521
# 2        F1  0.676829
# 3  Log_Loss  0.379747

# %% [markdown]
# <h3>SVM</h3>

# %%
#Q16
SVM = svm.SVC(class_weight='balanced')
SVM.fit(x_train, y_train)
# Out:
# SVC(class_weight='balanced')

# %%
#Q17
predictions = SVM.predict(x_test)

# %%
#Q18
SVM_Accuracy_Score = accuracy_score(y_test, predictions)
SVM_JaccardIndex = jaccard_score(y_test, predictions)
SVM_F1_Score = f1_score(y_test, predictions)

# %%
data_SVM = {'Metric':['Accuracy', 'Jaccard', 'F1'], 'Value':[SVM_Accuracy_Score, SVM_JaccardIndex, SVM_F1_Score]}
Report4 = pd.DataFrame(data=data_SVM)
print(Report4)
# Out:
#      Metric     Value
# 0  Accuracy  0.754198
# 1   Jaccard  0.456081
# 2        F1  0.626450

# %% [markdown]
# <h2>Report</h2>

# %%
#Q19
data = {'Accuracy':[KNN_Accuracy_Score, Tree_Accuracy_Score, LR_Accuracy_Score, SVM_Accuracy_Score],
       'Jaccard':[KNN_JaccardIndex, Tree_JaccardIndex, LR_JaccardIndex, SVM_JaccardIndex], 
       'F1-Score':[KNN_F1_Score, Tree_F1_Score, LR_F1_Score, SVM_F1_Score], 
       'Log_Loss':['-', '-', '-', LR_Log_Loss]}

indexes = ['KNN', 'Decision Tree', 'Logistic Regression', 'SVM']
Report_final = pd.DataFrame(data=data, index=indexes)
print(Report_final)
# Out:
#                      Accuracy   Jaccard  F1-Score  Log_Loss
# KNN                  0.818321  0.425121  0.596610         -
# Decision Tree        0.746565  0.380597  0.551351         -
# Logistic Regression  0.838168  0.511521  0.676829         -
# SVM                  0.754198  0.456081  0.626450  0.379747

# %%
metrics_dict = {
    'Model': ['Linear Regression', 'KNN', 'Decision Tree', 'Logistic Regression', 'SVM'],
    'Accuracy Score': [None, KNN_Accuracy_Score, Tree_Accuracy_Score, LR_Accuracy_Score, None],
    'Jaccard Index': [None, KNN_JaccardIndex, Tree_JaccardIndex, LR_JaccardIndex, None],
    'F1 Score': [None, KNN_F1_Score, Tree_F1_Score, LR_F1_Score, None],
    'Log Loss': [None, None, None, LR_Log_Loss, None]
}

# Create a DataFrame from the dictionary
Report = pd.DataFrame(metrics_dict)

# Display the DataFrame
Report
# Out:
#                  Model  Accuracy Score  Jaccard Index  F1 Score  Log Loss
# 0    Linear Regression             NaN            NaN       NaN       NaN
# 1                  KNN        0.818321       0.425121  0.596610       NaN
# 2        Decision Tree        0.746565       0.380597  0.551351       NaN
# 3  Logistic Regression        0.838168       0.511521  0.676829  0.379747
# 4                  SVM             NaN            NaN       NaN       NaN
